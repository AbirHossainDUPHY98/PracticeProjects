# %% [markdown]
# #### read the transformed csv files and enforce dtypes, write it in parquet format

# %% [markdown]
# ### For this project, load layer is this simple. Because I will separate the files by cleaning and merging datasets and output the files in `csv` format. So , only read the `csv` files and write those in `parquet` format for efficient handling of the data files and analysis.
#  - I also realized the thing that I could directly merge the datasets and write it as `parquet` reducing a much heavier intermediate step of saving the files in `csv` format. But it would've taken much more time to change the transfromation code and run it again and then load level code and run again. This issue also arised from doing ETL on separate layers and not completing the testing first. But for practical reason of being efficient with time, I continued with this strategy and have decided to do it more efficiently via methods and logics learned here in the next projects.
# #### I don't have to write any code for the loading layer in this project. But if we used **SQL** like I did for the `Banking and Financial Sector Performance of Bangladesh` analysis I did earlier, I would have to do a whole lot more on this layer.
